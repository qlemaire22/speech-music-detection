# %% [markdown]
# # Test Data Augmentation

# %%
import sys
sys.path.append('..')
import smd.data as data
from IPython.display import Audio

# Test file

AUDIO_FILE_PATH = "/Users/quentin/Computer/DataSet/Music/speech_music_detection/gtzan/music_wav/redhot.wav"

audio = data.preprocessing.load_audio(AUDIO_FILE_PATH, duration=5)
print(audio.shape)
# Out:
# Using TensorFlow backend.
# (110250,)

# %%
Audio(audio, rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Time stretching

# %%
Audio(data.data_augmentation.time_stretching(audio)[0], rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.time_stretching(audio)[0], rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.time_stretching(audio)[0], rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.time_stretching(audio)[0], rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.time_stretching(audio)[0], rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Pitch shifting

# %%
Audio(data.data_augmentation.pitch_shifting(audio), rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.pitch_shifting(audio), rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.pitch_shifting(audio), rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.pitch_shifting(audio), rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(data.data_augmentation.pitch_shifting(audio), rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Total

# %%
audio_transformed = data.data_augmentation.time_stretching(audio)[0]
audio_transformed = data.data_augmentation.pitch_shifting(audio_transformed)
Audio(audio_transformed, rate=22050)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
